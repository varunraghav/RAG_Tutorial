# %% [markdown]
# # Introduction

# %% [markdown]
# # Dataset

# %% [markdown]
# # Install and Load

# %%
# %pip install llama-index-llms-openai
# %pip install llama-index
# %pip install pyvis
# %pip install arize-phoenix[evals]
# %pip install llama-index-callbacks-arize-phoenix
# Out:
# Requirement already satisfied: llama-index-llms-openai in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (0.3.10)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.4 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-llms-openai) (0.12.9)
# Requirement already satisfied: openai<2.0.0,>=1.57.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-llms-openai) (1.57.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.11.10)
# Requirement already satisfied: dataclasses-json in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.2.0)
# Requirement already satisfied: httpx in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.28.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.1)
# Requirement already satisfied: nltk>3.8.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (0.8.0)
# Requirement already satisfied: sniffio in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.57.1->llama-index-llms-openai) (3.4)
# Requirement already satisfied: certifi in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2022.7.9)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (0.12.9)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.9 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.12.9)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.57.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (3.11.10)
# Requirement already satisfied: dataclasses-json in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2024.2.0)
# Requirement already satisfied: httpx in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (0.28.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (3.1)
# Requirement already satisfied: numpy in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.1.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.1.4)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.5.17)
# Requirement already satisfied: click in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (2022.7.9)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (6.0.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.4)
# Requirement already satisfied: anyio in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.5.0)
# Requirement already satisfied: certifi in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (1.0.7)
# Requirement already satisfied: idna in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.0)
# Requirement already satisfied: sniffio in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.9->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pyvis
#   Obtaining dependency information for pyvis from https://files.pythonhosted.org/packages/ab/4b/e37e4e5d5ee1179694917b445768bdbfb084f5a59ecd38089d3413d4c70f/pyvis-0.3.2-py3-none-any.whl.metadata
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pyvis) (8.12.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pyvis) (3.1.4)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Obtaining dependency information for jsonpickle>=1.4.1 from https://files.pythonhosted.org/packages/86/7c/c06580145924f60342f669f6e71905f838083d00e4b141172a75d22a23fc/jsonpickle-4.0.1-py3-none-any.whl.metadata
#   Downloading jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: networkx>=1.11 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pyvis) (3.1)
# Requirement already satisfied: backcall in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: executing in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: asttokens in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 13.0 MB/s eta 0:00:00a 0:00:01
# Downloading jsonpickle-4.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-4.0.1 pyvis-0.3.2
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: arize-phoenix[evals]
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-callbacks-arize-phoenix
#   Obtaining dependency information for llama-index-callbacks-arize-phoenix from https://files.pythonhosted.org/packages/52/6e/3fdac7c98786e18983336f12edd3e3310ea76af21a7eb757b9daa88a4db7/llama_index_callbacks_arize_phoenix-0.3.0-py3-none-any.whl.metadata
#   Downloading llama_index_callbacks_arize_phoenix-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting arize-phoenix>=3.0.3 (from llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for arize-phoenix>=3.0.3 from https://files.pythonhosted.org/packages/db/86/00c71568e11b13c63f686e6d9c2372b233c79ab7fc208881435b313d81c0/arize_phoenix-7.8.0-py3-none-any.whl.metadata
#   Downloading arize_phoenix-7.8.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-callbacks-arize-phoenix) (0.12.9)
# Collecting openinference-instrumentation-llama-index>=3.0.0 (from llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for openinference-instrumentation-llama-index>=3.0.0 from https://files.pythonhosted.org/packages/c0/78/365536597187ea59968fa57b5a5e22cee54ca17bda12bd16b774b7f181c4/openinference_instrumentation_llama_index-3.1.3-py3-none-any.whl.metadata
#   Downloading openinference_instrumentation_llama_index-3.1.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aioitertools in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.7.1)
# Requirement already satisfied: aiosqlite in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.18.0)
# Requirement already satisfied: alembic<2,>=1.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.13.3)
# Collecting arize-phoenix-evals>=0.13.1 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for arize-phoenix-evals>=0.13.1 from https://files.pythonhosted.org/packages/2b/f7/d16d8498a81fd1663b84898e0dae6d94757f9aaaa53ebd7c554dc06270b9/arize_phoenix_evals-0.19.0-py3-none-any.whl.metadata
#   Downloading arize_phoenix_evals-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting arize-phoenix-otel>=0.5.1 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for arize-phoenix-otel>=0.5.1 from https://files.pythonhosted.org/packages/9c/f3/f2390a9d7b3ee46b28a8ccee6510a489ae0974f31b51c67d79cab4c45ef8/arize_phoenix_otel-0.6.1-py3-none-any.whl.metadata
#   Downloading arize_phoenix_otel-0.6.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting authlib (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for authlib from https://files.pythonhosted.org/packages/63/c6/6a14bb00f963597d675fa63f060eb6db3fdb54bbf01d94768f51d067f578/Authlib-1.4.0-py2.py3-none-any.whl.metadata
#   Downloading Authlib-1.4.0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: cachetools in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (5.3.1)
# Requirement already satisfied: fastapi in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.115.6)
# Collecting grpc-interceptor (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for grpc-interceptor from https://files.pythonhosted.org/packages/15/ac/8d53f230a7443401ce81791ec50a3b0e54924bf615ad287654fa4a2f5cdc/grpc_interceptor-0.15.4-py3-none-any.whl.metadata
#   Downloading grpc_interceptor-0.15.4-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: grpcio in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.68.1)
# Requirement already satisfied: httpx in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.28.0)
# Requirement already satisfied: jinja2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (3.1.4)
# Requirement already satisfied: numpy!=2.0.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.26.4)
# Collecting openinference-instrumentation>=0.1.12 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for openinference-instrumentation>=0.1.12 from https://files.pythonhosted.org/packages/98/9e/78eeaa7917fece691c0ee48a9c514382f9cb3af2970d8254ce2a194a5b78/openinference_instrumentation-0.1.20-py3-none-any.whl.metadata
#   Downloading openinference_instrumentation-0.1.20-py3-none-any.whl.metadata (4.7 kB)
# Collecting openinference-semantic-conventions>=0.1.12 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for openinference-semantic-conventions>=0.1.12 from https://files.pythonhosted.org/packages/f0/fb/ea6c04bb12b2e5ade3faf32b24d45ffce9a21a1468ea179de96ceec1fb3d/openinference_semantic_conventions-0.1.12-py3-none-any.whl.metadata
#   Downloading openinference_semantic_conventions-0.1.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting opentelemetry-exporter-otlp (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for opentelemetry-exporter-otlp from https://files.pythonhosted.org/packages/cf/54/2a84533f39bb240958d691bb3ddf1c3fb6a92356654fb2e02a210f65ce6b/opentelemetry_exporter_otlp-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: opentelemetry-proto>=1.12.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.29.0)
# Requirement already satisfied: opentelemetry-semantic-conventions in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.50b0)
# Requirement already satisfied: pandas>=1.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.1.4)
# Requirement already satisfied: protobuf<6.0,>=3.20.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (5.29.1)
# Requirement already satisfied: psutil in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (5.9.0)
# Requirement already satisfied: pyarrow in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (11.0.0)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=1.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.10.5)
# Requirement already satisfied: python-multipart in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.0.20)
# Requirement already satisfied: scikit-learn in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.4.2)
# Requirement already satisfied: scipy in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.10.1)
# Requirement already satisfied: sqlalchemy[asyncio]<3,>=2.0.4 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.0.36)
# Collecting sqlean-py>=3.45.1 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for sqlean-py>=3.45.1 from https://files.pythonhosted.org/packages/aa/49/6475f7ee86f85cc5be1742ff38cf69ffaa433ffba1e7f298e8b091447e37/sqlean.py-3.47.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading sqlean.py-3.47.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Requirement already satisfied: starlette in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.41.3)
# Collecting strawberry-graphql==0.253.1 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for strawberry-graphql==0.253.1 from https://files.pythonhosted.org/packages/24/b3/4745158fe8ebcd89bea2bdc6c070ef7a750bea52f6db299ae4fdc1bb2691/strawberry_graphql-0.253.1-py3-none-any.whl.metadata
#   Downloading strawberry_graphql-0.253.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: tqdm in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (4.12.2)
# Requirement already satisfied: uvicorn in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.32.1)
# Requirement already satisfied: websockets in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (14.1)
# Collecting wrapt>=1.17 (from arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for wrapt>=1.17 from https://files.pythonhosted.org/packages/65/46/5a917ce85b5c3b490d35c02bf71aedaa9f2f63f2d15d9949cc4ba56e8ba9/wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql==0.253.1->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for graphql-core<3.4.0,>=3.2.0 from https://files.pythonhosted.org/packages/e3/dc/078bd6b304de790618ebb95e2aedaadb78f4527ac43a9ad8815f006636b6/graphql_core-3.2.5-py3-none-any.whl.metadata
#   Downloading graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from strawberry-graphql==0.253.1->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.8.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (3.11.10)
# Requirement already satisfied: dataclasses-json in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2024.2.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (3.1)
# Requirement already satisfied: nltk>3.8.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (9.5.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (0.9.0)
# Requirement already satisfied: opentelemetry-api in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openinference-instrumentation-llama-index>=3.0.0->llama-index-callbacks-arize-phoenix) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from openinference-instrumentation-llama-index>=3.0.0->llama-index-callbacks-arize-phoenix) (0.50b0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (6.0.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.18.3)
# Requirement already satisfied: Mako in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from alembic<2,>=1.3.0->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.3.5)
# Requirement already satisfied: click in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (8.1.7)
# Requirement already satisfied: joblib in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2022.7.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic!=2.0.*,<3,>=1.0->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from pydantic!=2.0.*,<3,>=1.0->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from sqlalchemy[asyncio]<3,>=2.0.4->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (0.4.3)
# Requirement already satisfied: cryptography in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from authlib->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (39.0.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-callbacks-arize-phoenix) (3.23.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from starlette->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpx->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from jinja2->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.1.1)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from opentelemetry-api->openinference-instrumentation-llama-index>=3.0.0->llama-index-callbacks-arize-phoenix) (6.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.29.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.29.0)
# Collecting opentelemetry-exporter-otlp-proto-http==1.29.0 (from opentelemetry-exporter-otlp->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-http==1.29.0 from https://files.pythonhosted.org/packages/31/49/a1c3d24e8fe73b5f422e21b46c24aed3db7fd9427371c06442e7bdfe4d3b/opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.29.0->opentelemetry-exporter-otlp->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.29.0)
# Requirement already satisfied: packaging>=18.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation->openinference-instrumentation-llama-index>=3.0.0->llama-index-callbacks-arize-phoenix) (24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from scikit-learn->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->openinference-instrumentation-llama-index>=3.0.0->llama-index-callbacks-arize-phoenix) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.7.0->strawberry-graphql==0.253.1->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from cryptography->authlib->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (1.15.1)
# Requirement already satisfied: pycparser in /Users/varunraghav/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography->authlib->arize-phoenix>=3.0.3->llama-index-callbacks-arize-phoenix) (2.21)
# Downloading llama_index_callbacks_arize_phoenix-0.3.0-py3-none-any.whl (2.2 kB)
# Downloading arize_phoenix-7.8.0-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 13.4 MB/s eta 0:00:0000:0100:01
# Downloading strawberry_graphql-0.253.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 22.6 MB/s eta 0:00:00
# Downloading openinference_instrumentation_llama_index-3.1.3-py3-none-any.whl (25 kB)
# Downloading arize_phoenix_evals-0.19.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 6.4 MB/s eta 0:00:00
# Downloading arize_phoenix_otel-0.6.1-py3-none-any.whl (10 kB)
# Downloading openinference_instrumentation-0.1.20-py3-none-any.whl (14 kB)
# Downloading openinference_semantic_conventions-0.1.12-py3-none-any.whl (9.1 kB)
# Downloading sqlean.py-3.47.0-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.7 MB/s eta 0:00:0000:01
# Downloading wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Downloading Authlib-1.4.0-py2.py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 23.6 MB/s eta 0:00:00
# Downloading grpc_interceptor-0.15.4-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp-1.29.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl (17 kB)
# Downloading graphql_core-3.2.5-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.2/203.2 kB 23.5 MB/s eta 0:00:00
# Installing collected packages: sqlean-py, wrapt, openinference-semantic-conventions, grpc-interceptor, graphql-core, strawberry-graphql, authlib, arize-phoenix-evals, opentelemetry-exporter-otlp-proto-http, openinference-instrumentation, opentelemetry-exporter-otlp, openinference-instrumentation-llama-index, arize-phoenix-otel, arize-phoenix, llama-index-callbacks-arize-phoenix
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-macos 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.17.2 which is incompatible.
# letta 0.6.3 requires html2text<2021.0.0,>=2020.1.16, but you have html2text 2024.2.26 which is incompatible.
# letta 0.6.3 requires pydantic<2.10.0,>=2.7.4, but you have pydantic 2.10.5 which is incompatible.
# letta 0.6.3 requires python-multipart<0.0.10,>=0.0.9, but you have python-multipart 0.0.20 which is incompatible.
# letta 0.6.3 requires typer[all]<0.10.0,>=0.9.0, but you have typer 0.15.1 which is incompatible.
# Successfully installed arize-phoenix-7.8.0 arize-phoenix-evals-0.19.0 arize-phoenix-otel-0.6.1 authlib-1.4.0 graphql-core-3.2.5 grpc-interceptor-0.15.4 llama-index-callbacks-arize-phoenix-0.3.0 openinference-instrumentation-0.1.20 openinference-instrumentation-llama-index-3.1.3 openinference-semantic-conventions-0.1.12 opentelemetry-exporter-otlp-1.29.0 opentelemetry-exporter-otlp-proto-http-1.29.0 sqlean-py-3.47.0 strawberry-graphql-0.253.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from typing import Sequence, List

from llama_index.llms.openai import OpenAI
from llama_index.core.llms import ChatMessage
from llama_index.core.tools import BaseTool, FunctionTool

import nest_asyncio

nest_asyncio.apply()

# %%
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass("Enter your Open API key: ")
# Out:
# Enter your Open API key: ········

# %%
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core import Document
from llama_index.core import Settings

# Update Settings
Settings.chunk_size = 512
Settings.chunk_overlap = 64
Settings.llm = OpenAI(model="gpt-4o-mini")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")

# %%
# Load indices from disk
from llama_index.core import load_index_from_storage

years = [2022, 2021, 2020, 2019]
index_set = {}
for year in years:
    storage_context = StorageContext.from_defaults(
        persist_dir=f"./storage/{year}"
    )
    cur_index = load_index_from_storage(
        storage_context,
    )
    index_set[year] = cur_index

# %%
from llama_index.core.tools import QueryEngineTool, ToolMetadata

individual_query_engine_tools = []

for year in years:
    # Step 1: Retrieve the query engine for the current year's vector index
    query_engine = index_set[year].as_query_engine()
    print(f"Created query engine for {year}.")

    # Step 2: Define metadata for the query engine tool
    metadata = ToolMetadata(
        name=f"vector_index_{year}",
        description=(
            "Useful for when you want to answer queries about the"
            f" {year} SEC 10-K for Uber."
        ),
    )
    print(f"ToolMetadata for {year}: {metadata}")

    # Step 3: Create a QueryEngineTool for this year
    tool = QueryEngineTool(
        query_engine=query_engine,
        metadata=metadata,
    )
    print(f"Created QueryEngineTool for {year}: {tool}")

    # Step 4: Add the tool to the list
    individual_query_engine_tools.append(tool)
    print(f"Added tool for {year} to the list.\n")
# Out:
# Created query engine for 2022.
# ToolMetadata for 2022: ToolMetadata(description='Useful for when you want to answer queries about the 2022 SEC 10-K for Uber.', name='vector_index_2022', fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>, return_direct=False)
# Created QueryEngineTool for 2022: <llama_index.core.tools.query_engine.QueryEngineTool object at 0x178aa7fd0>
# Added tool for 2022 to the list.
#
# Created query engine for 2021.
# ToolMetadata for 2021: ToolMetadata(description='Useful for when you want to answer queries about the 2021 SEC 10-K for Uber.', name='vector_index_2021', fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>, return_direct=False)
# Created QueryEngineTool for 2021: <llama_index.core.tools.query_engine.QueryEngineTool object at 0x17834c950>
# Added tool for 2021 to the list.
#
# Created query engine for 2020.
# ToolMetadata for 2020: ToolMetadata(description='Useful for when you want to answer queries about the 2020 SEC 10-K for Uber.', name='vector_index_2020', fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>, return_direct=False)
# Created QueryEngineTool for 2020: <llama_index.core.tools.query_engine.QueryEngineTool object at 0x285b5c710>
# Added tool for 2020 to the list.
#
# Created query engine for 2019.
# ToolMetadata for 2019: ToolMetadata(description='Useful for when you want to answer queries about the 2019 SEC 10-K for Uber.', name='vector_index_2019', fn_schema=<class 'llama_index.core.tools.types.DefaultToolFnSchema'>, return_direct=False)
# Created QueryEngineTool for 2019: <llama_index.core.tools.query_engine.QueryEngineTool object at 0x285b5c3d0>
# Added tool for 2019 to the list.

# %%
from llama_index.core.query_engine import SubQuestionQueryEngine

query_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=individual_query_engine_tools,
)

# %%
query_engine_tool = QueryEngineTool(
    query_engine=query_engine,
    metadata=ToolMetadata(
        name="sub_question_query_engine",
        description=(
            "useful for when you want to answer queries that require analyzing"
            " multiple SEC 10-K documents for Uber"
        ),
    ),
)
tools = individual_query_engine_tools + [query_engine_tool]

# %%
llm = OpenAI(model="gpt-4o-mini")

# %%
from llama_index.core.agent import AgentRunner
from llama_index.agent.openai import OpenAIAgentWorker, OpenAIAgent

# Option 1: Initialize OpenAIAgent
agent = OpenAIAgent.from_tools(tools, llm=llm, verbose=True)


# # Option 2: Initialize AgentRunner with OpenAIAgentWorker
# openai_step_engine = OpenAIAgentWorker.from_tools(tools, llm=llm, verbose=True)
# agent = AgentRunner(openai_step_engine)

# %%
agent.chat("Hi")
# Out:
# Added user message to memory: Hi
# AgentChatResponse(response='Hello! How can I assist you today?', sources=[], source_nodes=[], is_dummy_stream=False, metadata=None)

# %%
response = agent.chat(
    "What were some of the biggest risk factors in 2026 for Uber?"
)
print(str(response))
# Out:
# Added user message to memory: What were some of the biggest risk factors in 2026 for Uber?
# === Calling Function ===
# Calling function: vector_index_2022 with args: {"input":"risk factors 2026"}
